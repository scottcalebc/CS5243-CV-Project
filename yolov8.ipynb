# %% [markdown]
# <a href="https://colab.research.google.com/github/scottcalebc/CS5243-CV-Project/blob/initial-yolo-model/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 9.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import Pre-Trained Yolov8 Mode

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
# display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)
#
# OS                  Linux-5.15.120+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.68 GB
# CPU                 Intel Xeon 2.30GHz
# CUDA                11.8
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.3>=1.4.1
# torch               ✅ 2.0.1+cu118>=1.8.0
# torchvision         ✅ 0.15.2+cu118>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %% [markdown]
# # Train Yolov8 on COCO128 dataset

# %%
model = YOLO('yolov8n.pt')

results = model.train(data='coco128.yaml', epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 77.3MB/s]
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Train Yolov8 on VisDrone Dataset
#
# ## Dataset properties
# This dataset was collected using various drone platforms under different scenarios and weather and lighting condition, with manually annotated boxes on
# mostly humans and city objects
#
# ## Dataset structure
#  - Task 1: Object detection in images
#  - Task 2: Object detection in videos
#  - Task 3: Single-object tracking
#  - Task 4: Multi-object tracking
#  - Task 5: Crowd counting
#
#
#
#  This could be a useful dataset to compare against drone footage for goal of
#  project

# %%
model = YOLO('yolov8n.pt')

results = model.train(data='VisDrone.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
